# %% [markdown]
# ## XOR 이해하기 with Keras

# %%
# tensorflow와 tf.keras를 임포트합니다
import tensorflow as tf
from tensorflow import keras

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
# 헬퍼(helper) 라이브러리를 임포트합니다
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Remember !! XOR : 모두 같으면 0

# %%
x_data = [[0, 0],
          [0, 1],
          [1, 0],
          [1, 1]]

y_data = [0,
          1,
          1,
          0]

x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

# %%
plt.scatter(x_data[:, 0], x_data[:, 1], c=y_data)

# %%
from tensorflow.keras import layers
from tensorflow.keras import activations
from tensorflow.keras import optimizers
from tensorflow.keras import models

# %%
model = models.Sequential()
model.add(layers.Dense(5, input_dim=2))
model.add(layers.Activation('tanh'))
model.add(layers.Dense(4))
model.add(layers.Activation('tanh'))
model.add(layers.Dense(3))
model.add(layers.Activation('tanh'))
model.add(layers.Dense(2))
model.add(layers.Activation('tanh'))
model.add(layers.Dense(1))
model.add(layers.Activation('sigmoid'))

# %%
sgd = optimizers.SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 5)                 15
# _________________________________________________________________
# activation (Activation)      (None, 5)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 24
# _________________________________________________________________
# activation_1 (Activation)    (None, 4)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 15
# _________________________________________________________________
# activation_2 (Activation)    (None, 3)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 8
# ...

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_xor.png', show_shapes=True)
# Out:
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %%
history = model.fit(x_data, y_data,  batch_size=2, epochs=600)
# Out:
# Train on 4 samples
# Epoch 1/600
# 4/4 [==============================] - 1s 138ms/sample - loss: 0.7304 - accuracy: 0.2500
# Epoch 2/600
# 4/4 [==============================] - 0s 0s/sample - loss: 0.7846 - accuracy: 0.2500
# Epoch 3/600
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.7732 - accuracy: 0.2500
# Epoch 4/600
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.7030 - accuracy: 0.2500
# Epoch 5/600
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6980 - accuracy: 0.2500
# Epoch 6/600
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6942 - accuracy: 0.5000
# Epoch 7/600
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.7507 - accuracy: 0.5000
# Epoch 8/600
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6866 - accuracy: 0.2500
# Epoch 9/600
# 4/4 [==============================] - 0s 0s/sample - loss: 0.7393 - accuracy: 0.2500
# Epoch 10/600
# ...

# %% [markdown]
# ### 학습 결과 그려보기

# %%
plt.plot(history.history['loss'])
plt.title('Loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
plt.plot(history.history['accuracy'])
plt.title('Training accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %% [markdown]
# ###  확률 찍어보기

# %%
hypothesis = model.predict(x_data)
print(hypothesis)
# Out:
# [[0.00372433]
#  [0.9947088 ]
#  [0.99476874]
#  [0.00500811]]

# %%
predicted = hypothesis > 0.5
print(predicted)
# Out:
# [[False]
#  [ True]
#  [ True]
#  [False]]

# %% [markdown]
# ### 생각해보기

# %% [markdown]
# * XOR 분류에서 정확도 75의 의미는?

# %% [markdown]
# ### XOR 분류를 2차원 공간에서 한다면 Y가 0이나 1인 데이터를 한 번에 묶을 경우 무조건적으로 하나의 데이터가 동떨어져 정확도는 75%가 된다. 하지만 이를 3차원 공간에서 분류하면 모든 데이터를 두 종류로 분류할 수 있으므로 정확도는 100%가 된다.
