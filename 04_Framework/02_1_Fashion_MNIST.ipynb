# %% [markdown]
# 참고 :
# * https://github.com/tensorflow/docs-l10n/blob/master/site/ko/tutorials/keras/classification.ipynb
# * https://archive.is/fY0FO

# %%
# tensorflow와 tf.keras를 임포트합니다
import tensorflow as tf
from tensorflow import keras

# 헬퍼(helper) 라이브러리를 임포트합니다
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.0.0

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# * 이미지는 28x28 크기의 넘파이 배열이고 픽셀 값은 0과 255 사이입니다. 레이블(label)은 0에서 9까지의 정수 배열입니다. 이 값은 이미지에 있는 옷의 클래스(class)를 나타냅니다:
#
#
# * 레이블	클래스
# ```
# 0	T-shirt/top
# 1	Trouser
# 2	Pullover
# 3	Dress
# 4	Coat
# 5	Sandal
# 6	Shirt
# 7	Sneaker
# 8	Bag
# 9	Ankle boot
# ```

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# ### 데이터 탐색

# %%
plt.figure()
idx_to_draw = 2000 # 바꾸어보세요
plt.imshow(train_images[idx_to_draw])

lbl = train_labels[idx_to_draw]

plt.title('#{} - {} {}'.format(idx_to_draw, lbl, class_names[lbl]))
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# ### Data 전처리

# %% [markdown]
# 신경망 모델에 주입하기 전에 이 값의 범위를 0~1 사이로 조정하겠습니다. 이렇게 하려면 255로 나누어야 합니다. 훈련 세트와 테스트 세트를 동일한 방식으로 전처리하는 것이 중요합니다:

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ### TDDO: 학습 코드를 위의 참조 url 을 이용하여 완성해보세요

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, batch_size=600, epochs=100)
# Out:
# Train on 60000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.9195 - accuracy: 0.6791
# Epoch 2/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.4992 - accuracy: 0.8281
# Epoch 3/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.4283 - accuracy: 0.8498
# Epoch 4/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.3934 - accuracy: 0.8614
# Epoch 5/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.3691 - accuracy: 0.8688
# Epoch 6/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.3475 - accuracy: 0.8761
# Epoch 7/100
# 60000/60000 [==============================] - 2s 27us/sample - loss: 0.3313 - accuracy: 0.8808s - loss: 0.3292 - ac
# Epoch 8/100
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.3183 - accuracy: 0.8863
# Epoch 9/100
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.3031 - accuracy: 0.8895
# Epoch 10/100
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.3014 - accuracy: 0.8900
# Epoch 11/100
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.2890 - accuracy: 0.8950
# Epoch 12/100
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.2760 - accuracy: 0.9004
# Epoch 13/100
# 60000/60000 [==============================] - 2s 38us/sample - loss: 0.2745 - accuracy: 0.8993
# Epoch 14/100
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.2635 - accuracy: 0.9036
# Epoch 15/100
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.2615 - accuracy: 0.9046
# Epoch 16/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.2567 - accuracy: 0.9063
# Epoch 17/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.2508 - accuracy: 0.9077
# Epoch 18/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.2423 - accuracy: 0.9115
# Epoch 19/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.2390 - accuracy: 0.9122
# Epoch 20/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.2328 - accuracy: 0.9145
# Epoch 21/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.2264 - accuracy: 0.9172s - loss: 0.2270 - accuracy: 0.91
# Epoch 22/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.2248 - accuracy: 0.9165
# Epoch 23/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.2172 - accuracy: 0.9195s - loss: 0.2169 - accuracy:
# Epoch 24/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.2161 - accuracy: 0.9214
# Epoch 25/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.2125 - accuracy: 0.9213
# Epoch 26/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.2107 - accuracy: 0.9219
# Epoch 27/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1999 - accuracy: 0.9265
# Epoch 28/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.2015 - accuracy: 0.9259
# Epoch 29/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.1969 - accuracy: 0.9272
# Epoch 30/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1915 - accuracy: 0.9290
# Epoch 31/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1903 - accuracy: 0.9301
# Epoch 32/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1886 - accuracy: 0.9303
# Epoch 33/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1876 - accuracy: 0.9316
# Epoch 34/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1807 - accuracy: 0.9322
# Epoch 35/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1819 - accuracy: 0.9331
# Epoch 36/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1789 - accuracy: 0.9339
# Epoch 37/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1733 - accuracy: 0.9358
# Epoch 38/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.1712 - accuracy: 0.9360
# Epoch 39/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1687 - accuracy: 0.9374
# Epoch 40/100
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.1702 - accuracy: 0.9364
# Epoch 41/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1683 - accuracy: 0.9373
# Epoch 42/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1624 - accuracy: 0.9394
# Epoch 43/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1589 - accuracy: 0.9407
# Epoch 44/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1554 - accuracy: 0.9436
# Epoch 45/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.1608 - accuracy: 0.9413
# Epoch 46/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.1548 - accuracy: 0.9418
# Epoch 47/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1501 - accuracy: 0.9442
# Epoch 48/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1482 - accuracy: 0.9458
# Epoch 49/100
# 60000/60000 [==============================] - 1s 20us/sample - loss: 0.1478 - accuracy: 0.9453
# Epoch 50/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1454 - accuracy: 0.9466s - loss: 0.1448 - accuracy
# Epoch 51/100
# 60000/60000 [==============================] - 1s 19us/sample - loss: 0.1462 - accuracy: 0.9463
# Epoch 52/100
# 60000/60000 [==============================] - 1s 21us/sample - loss: 0.1447 - accuracy: 0.9464
# Epoch 53/100
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.1409 - accuracy: 0.9483
# Epoch 54/100
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.1399 - accuracy: 0.9479
# Epoch 55/100
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.1378 - accuracy: 0.9488
# Epoch 56/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1333 - accuracy: 0.9509
# Epoch 57/100
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.1314 - accuracy: 0.9510
# Epoch 58/100
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.1372 - accuracy: 0.9490
# Epoch 59/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1349 - accuracy: 0.9505
# Epoch 60/100
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.1263 - accuracy: 0.9529
# Epoch 61/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1317 - accuracy: 0.9516
# Epoch 62/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1216 - accuracy: 0.9545
# Epoch 63/100
# 60000/60000 [==============================] - 1s 23us/sample - loss: 0.1203 - accuracy: 0.9560
# Epoch 64/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1240 - accuracy: 0.9532
# Epoch 65/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1267 - accuracy: 0.9532
# Epoch 66/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1226 - accuracy: 0.9546
# Epoch 67/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1214 - accuracy: 0.9547
# Epoch 68/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1189 - accuracy: 0.9561
# Epoch 69/100
# 60000/60000 [==============================] - 1s 22us/sample - loss: 0.1181 - accuracy: 0.9564
# Epoch 70/100
# 60000/60000 [==============================] - 1s 24us/sample - loss: 0.1181 - accuracy: 0.9565
# Epoch 71/100
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.1121 - accuracy: 0.9579
# Epoch 72/100
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.1214 - accuracy: 0.9548
# Epoch 73/100
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.1118 - accuracy: 0.9583
# Epoch 74/100
# 60000/60000 [==============================] - 2s 38us/sample - loss: 0.1135 - accuracy: 0.9580
# Epoch 75/100
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.1161 - accuracy: 0.9567
# Epoch 76/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.1111 - accuracy: 0.9591
# Epoch 77/100
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.1106 - accuracy: 0.9580
# Epoch 78/100
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.1024 - accuracy: 0.9624
# Epoch 79/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.1047 - accuracy: 0.9610
# Epoch 80/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.1070 - accuracy: 0.9599s - loss: 0.1072 - accuracy: 0.95
# Epoch 81/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.1021 - accuracy: 0.9624
# Epoch 82/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.1028 - accuracy: 0.9619
# Epoch 83/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.1031 - accuracy: 0.9617
# Epoch 84/100
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.1022 - accuracy: 0.9624
# Epoch 85/100
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.1053 - accuracy: 0.9613
# Epoch 86/100
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.1022 - accuracy: 0.9628
# Epoch 87/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.1001 - accuracy: 0.9631
# Epoch 88/100
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.0961 - accuracy: 0.9640
# Epoch 89/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.1011 - accuracy: 0.9629
# Epoch 90/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.0963 - accuracy: 0.9640
# Epoch 91/100
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.0997 - accuracy: 0.9626
# Epoch 92/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.0954 - accuracy: 0.9644
# Epoch 93/100
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.0931 - accuracy: 0.9657
# Epoch 94/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.0948 - accuracy: 0.9646
# Epoch 95/100
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.0975 - accuracy: 0.9636
# Epoch 96/100
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.0903 - accuracy: 0.9664
# Epoch 97/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.0914 - accuracy: 0.9663
# Epoch 98/100
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.0912 - accuracy: 0.9664
# Epoch 99/100
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.0891 - accuracy: 0.9674
# Epoch 100/100
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.0891 - accuracy: 0.9674

# %%
#그래프 그리기

plt.cla()
plt.clf()

accuracy= history.history['accuracy']
loss = history.history['loss']
epochs = range(1, len(accuracy) + 1)

plt.plot(epochs, accuracy, 'r', label = 'accuracy')
plt.plot(epochs, loss, 'b', label = 'loss')
plt.title('Training accuracy and loss')
plt.legend()
plt.figure()

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\n테스트 정확도:', test_acc)
# Out:
# 10000/1 - 1s - loss: 0.2268 - accuracy: 0.8964
#
# 테스트 정확도: 0.8964

# %%
predictions = model.predict(test_images)

# %%
predictions[0]
# Out:
# array([1.3230117e-14, 6.5553968e-18, 1.3240720e-14, 3.6471007e-16,
#        6.0883297e-13, 3.9302881e-07, 4.3421218e-09, 4.2936921e-07,
#        3.0407933e-12, 9.9999917e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions,  test_labels)
plt.show()

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions,  test_labels)
plt.show()

# %%
# 처음 X 개의 테스트 이미지와 예측 레이블, 진짜 레이블을 출력합니다
# 올바른 예측은 파랑색으로 잘못된 예측은 빨강색으로 나타냅니다
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions, test_labels)
plt.show()

# %%
# 테스트 세트에서 이미지 하나를 선택합니다
img = test_images[0]

print(img.shape)
# Out:
# (28, 28)

# %%
# 이미지 하나만 사용할 때도 배치에 추가합니다
img = (np.expand_dims(img,0))

print(img.shape)
# Out:
# (1, 28, 28)

# %%
predictions_single = model.predict(img)

print(predictions_single)
# Out:
# [[1.3230091e-14 6.5553716e-18 1.3240669e-14 3.6470870e-16 6.0883297e-13
#   3.9302807e-07 4.3421138e-09 4.2936838e-07 3.0407933e-12 9.9999917e-01]]

# %%
plot_value_array(0, predictions_single, test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)

# %%
np.argmax(predictions_single[0])
# Out:
# 9
